# %% [markdown]
# # Datalad Example

# %% [markdown]
# ### This example showcase how you can download and get files from a datalad dataset

# %%
from uniharmony import verbosity
from uniharmony.datasets import load_onharmony


verbosity("warning")

# %%
load_onharmony(subjects="all", sessions="all", modalities="anat", data_types="T1w", extensions=".json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 load_onharmony(subjects="all", sessions="all", modalities="anat", data_types="T1w", extensions=".json")
#
# NameError: name 'load_onharmony' is not defined

# %%
# Out:
# /home/nnieto/Nico/UniHarmonyProject/UniHarmony/.venv/bin/python: No module named uv
# Note: you may need to restart the kernel to use updated packages.
