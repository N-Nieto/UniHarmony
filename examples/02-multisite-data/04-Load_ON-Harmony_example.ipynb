# %% [markdown]
# # Datalad Example

# %% [markdown]
# ### This example showcase how you can download and get files from a datalad dataset

# %%
from uniharmony import verbosity
from uniharmony.datasets import clean_tmp_folder, load_ONharmony


verbosity("debug")

# %%
load_ONharmony(
    subjects="16981",
    sessions="NOT4GEP001",
    modalities="anat",
    suffixes="T1w",
    extensions=".json",
)
# Out:
# 2026-05-06 14:12:50 [debug    ] Validating arguments
# 2026-05-06 14:12:50 [info     ] Visible dataset directory ready at /home/nnieto/Nico/UniHarmonyProject/UniHarmony/examples/02-multisite-data/ON-Harmony
# 2026-05-06 14:12:50 [debug    ] Hidden dataset path prepared: /tmp/datalad_cache
# 2026-05-06 14:12:50 [debug    ] Using hidden folder at /tmp/datalad_cache
# 2026-05-06 14:12:50 [debug    ] Source URL: https://github.com/OpenNeuroDatasets/ds004712.git
# 2026-05-06 14:12:50 [info     ] Cloning DataLad dataset...
# [INFO] Attempting a clone into /tmp/datalad_cache
# [INFO] Attempting to clone from https://github.com/OpenNeuroDatasets/ds004712.git to /tmp/datalad_cache
# [INFO] Start enumerating objects
# [INFO] Start counting objects
# [INFO] Start compressing objects
# [INFO] Start receiving objects
# [INFO] Start resolving deltas
# [INFO] Completed clone attempts for Dataset(/tmp/datalad_cache)
# [INFO] Remote origin not usable by git-annex; setting annex-ignore
# [INFO] https://github.com/OpenNeuroDatasets/ds004712.git/config download failed: Not Found
# 2026-05-06 14:12:59 [info     ] Skipping, file already in destination: sub-16981/ses-NOT4GEP001/anat/sub-16981_ses-NOT4GEP001_T1w.json
# 2026-05-06 14:12:59 [info     ] Copied derivative files to target directory.
# 2026-05-06 14:12:59 [info     ] Skipping, file already in destination: participants.tsv
# 2026-05-06 14:12:59 [info     ] Copied root files to target directory.

# %%
# Later, clean up the temporary cache
clean_tmp_folder("datalad_cache")
# Out:
# 2026-05-06 14:12:59 [info     ] Removing temporary files: /tmp/datalad_cache
# 2026-05-06 14:12:59 [info     ] Temporary cache removed successfully.
