# %% [markdown]
# # Datalad Example

# %% [markdown]
# ### This example showcase how you can download and get files from a datalad dataset

# %%
from uniharmony import verbosity
from uniharmony.datasets import load_onharmony


verbosity("debug")

# %%
load_onharmony(subjects="16981", sessions="NOT4GEP001", modalities="anat", tasks="T1w", extensions=".json", force_download=True)
# Out:
# 2026-05-01 11:53:16 [info     ] ✓ Visible dataset directory ready at /home/nnieto/Nico/UniHarmonyProject/UniHarmony/examples/02-multisite-data/ONHarmony
# 2026-05-01 11:53:16 [info     ] Force download dataset
# 2026-05-01 11:53:17 [info     ] Cloning DataLad dataset into hidden cache...
# 2026-05-01 11:53:17 [debug    ] Source URL: https://github.com/OpenNeuroDatasets/ds004712.git
# [INFO] Attempting a clone into /tmp/datalad_cache/ds004712
# [INFO] Attempting to clone from https://github.com/OpenNeuroDatasets/ds004712.git to /tmp/datalad_cache/ds004712
# [INFO] Start enumerating objects
# [INFO] Start counting objects
# [INFO] Start compressing objects
# [INFO] Start receiving objects
# [INFO] Start resolving deltas
# [INFO] Completed clone attempts for Dataset(/tmp/datalad_cache/ds004712)
# [INFO] Remote origin not usable by git-annex; setting annex-ignore
# [INFO] https://github.com/OpenNeuroDatasets/ds004712.git/config download failed: Not Found
# 2026-05-01 11:53:27 [debug    ] hidden_dataset_path created: /tmp/datalad_cache/ds004712
# [INFO] Ensuring presence of Dataset(/tmp/datalad_cache/ds004712) to get /tmp/datalad_cache/ds004712
# 2026-05-01 11:53:27 [debug    ] Processing directory: /tmp/datalad_cache/ds004712
# 2026-05-01 11:53:27 [debug    ] Processing directory: /tmp/datalad_cache/ds004712/sub-16981
# 2026-05-01 11:53:27 [debug    ] Processing directory: /tmp/datalad_cache/ds004712/sub-16981/ses-NOT4GEP001
# 2026-05-01 11:53:27 [debug    ] Processing directory: /tmp/datalad_cache/ds004712/sub-16981/ses-NOT4GEP001/anat
# 2026-05-01 11:53:27 [debug    ] Adding candidate file: <map object at 0x7f81c82f7010>
# 2026-05-01 11:53:27 [info     ] Getting: sub-16981/ses-NOT4GEP001/anat/sub-16981_ses-NOT4GEP001_T1w.json
# 2026-05-01 11:53:27 [debug    ] Dropped sub-16981/ses-NOT4GEP001/anat/sub-16981_ses-NOT4GEP001_T1w.json from hidden dataset to save space.
# 2026-05-01 11:53:27 [info     ]
# ✓ Copied files downloaded.
