# %% [markdown]
# (example_combatgam_in_mareos)=

# %% [markdown]
# # Benchmark NeuroComBat in MAREoS dataset

# %%
import warnings

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import balanced_accuracy_score

from uniharmony import verbosity
from uniharmony.combat import ComBatGAM
from uniharmony.datasets import load_MAREoS


sns.set_theme(style="whitegrid")
verbosity("debug")
warnings.filterwarnings(action="ignore", category=ConvergenceWarning)

# %% [markdown]
# ## 2) Load MAREoS benchmark dataset
# - `datasets = load_MAREoS()` loads simulated neuroimaging benchmark data.
# - The dataset contains multiple scenarios (`true` vs `eos` effects; `simple` vs `interaction`; example 1/2).

# %%
# Load the MAREoS dataset (made for benchmarking harmonization methods)
datasets = load_MAREoS()

# Define the different effects, effect types, and examples to iterate over
effects = ["true", "eos"]
effect_types = ["simple", "interaction"]
effect_examples = ["1", "2"]

random_state = 23

# Assign an empty list to each key in the results dictionary
unharmonized_results = []
neurocombat_results = []

# Define the harmonization model to use (NeuroComBat in this case)
harm_model = ComBatGAM()
# Out:
# 2026-04-16 18:37:09 [info     ] MAREoS datasets already exist at: /home/nnieto/.cache/uniharmony/MAREoS
# 2026-04-16 18:37:09 [info     ] Getting data file: /home/nnieto/.cache/uniharmony/MAREoS/public_datasets/eos_simple1_data.csv
# 2026-04-16 18:37:09 [info     ] Getting data file: /home/nnieto/.cache/uniharmony/MAREoS/public_datasets/eos_simple2_data.csv
# 2026-04-16 18:37:09 [info     ] Getting data file: /home/nnieto/.cache/uniharmony/MAREoS/public_datasets/eos_interaction1_data.csv
# 2026-04-16 18:37:09 [info     ] Getting data file: /home/nnieto/.cache/uniharmony/MAREoS/public_datasets/eos_interaction2_data.csv
# 2026-04-16 18:37:09 [info     ] Getting data file: /home/nnieto/.cache/uniharmony/MAREoS/public_datasets/true_simple1_data.csv
# 2026-04-16 18:37:09 [info     ] Getting data file: /home/nnieto/.cache/uniharmony/MAREoS/public_datasets/true_simple2_data.csv
# 2026-04-16 18:37:09 [info     ] Getting data file: /home/nnieto/.cache/uniharmony/MAREoS/public_datasets/true_interaction1_data.csv
# 2026-04-16 18:37:09 [info     ] Getting data file: /home/nnieto/.cache/uniharmony/MAREoS/public_datasets/true_interaction2_data.csv

# %% [markdown]
# ## 3) Experiment loop
# - Iterates all combinations:
#     - `effect` = `true` or `eos`
#     - `effect_type` = `simple` or `interaction`
#     - `example` = `1` or `2`
# - For each combination:
#     - Choose classifier: logistic regression for simple; random forest for interaction.
#     - Extract data: `X`, `y`, `sites`, `folds`.
#     - Do leave-one-fold-out cross-validation:
#         - train on folds != current fold
#         - test on fold == current fold
#     - Train baseline classifier on unharmonized training data and compute balanced accuracy on raw test.
#     - Harmonize training with `NeuroComBat.fit_transform(...)`, then train classifier, transform test, compute balanced accuracy.
# - Collect results into two lists and then into DataFrames.

# %%
for effect in effects:
    for e_types in effect_types:
        if e_types == "interaction":
            clf = RandomForestClassifier(n_estimators=10, random_state=random_state)
        elif e_types == "simple":
            clf = LogisticRegression(random_state=random_state)
        for e_example in effect_examples:
            example = effect + "_" + e_types + e_example
            print(f"Running experiment: {example}")
            data = datasets[example]

            sites = data["sites"]
            X = data["X"]
            folds = data["folds"]
            folds = pd.Series(folds)
            sites = data["sites"]

            target = data["y"]

            covars = target.ravel().reshape(-1, 1)

            for fold in folds.unique():
                # Train Data
                X = data["X"].copy()
                y = data["y"].copy()
                sites = data["sites"].copy()

                # Train Target
                X_train = X[data["folds"] != fold]
                site_train = sites[data["folds"] != fold]

                y_train = y[data["folds"] != fold]

                # Test data
                X_test = X[data["folds"] == fold]
                site_test = sites[data["folds"] == fold]

                # Test target
                y_test = y[data["folds"] == fold]

                # Unharmonized baseline model
                clf.fit(X_train, y_train)
                unharmonized_results.append(
                    [
                        balanced_accuracy_score(y_true=y_test, y_pred=clf.predict(X=X_test)),
                        fold,
                        effect,
                        e_types,
                        e_example,
                        example,
                    ]
                )

                # neuroComBat (do not include target as covariate - avoiding data leakage)
                X_train_harm = harm_model.fit_transform(X=X_train, sites=site_train, smooth_covariates=y_train.reshape(-1, 1))
                # Fit the model with the harmonized train
                clf.fit(X_train_harm, y_train)
                # harmonize the test data
                X_test_harm = harm_model.transform(X=X_test, sites=site_test, smooth_covariates=y_test.reshape(-1, 1))

                neurocombat_results.append(
                    [
                        balanced_accuracy_score(y_true=y_test, y_pred=clf.predict(X=X_test_harm)),
                        fold,
                        effect,
                        e_types,
                        e_example,
                        example,
                    ]
                )

# Results to datadframe
unharmonized_results = pd.DataFrame(data=unharmonized_results, columns=["bACC", "Fold", "Effect", "Type", "Example", "Name"])
unharmonized_results["Method"] = "Unharmonized Baseline"

neurocombat_results = pd.DataFrame(data=neurocombat_results, columns=["bACC", "Fold", "Effect", "Type", "Example", "Name"])
neurocombat_results["Method"] = "ComBatGAM"

results = pd.concat([unharmonized_results, neurocombat_results])
# Out:
# Running experiment: true_simple1
# 2026-04-16 18:37:12 [debug    ] Fitting
# 2026-04-16 18:37:12 [debug    ] Making design matrix
# 2026-04-16 18:37:12 [debug    ] Fitted site encoder: 8 sites
# 2026-04-16 18:37:12 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:37:12 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:37:12 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:37:12 [debug    ] Final formula for smoothing: y ~ x0 + x1 + x2 + x3 + x4 + x5 + x6 + x7 - 1
# 2026-04-16 18:37:12 [debug    ] Standardizing data across features
# 2026-04-16 18:37:12 [info     ] Smoothing more than 10 variables may take several minutes of computation.
# 2026-04-16 18:37:25 [debug    ] Standardization stats:
# 2026-04-16 18:37:25 [debug    ]   Grand mean range: [1.5774, 3.7007]
# 2026-04-16 18:37:25 [debug    ]   Pooled std range: [0.1476, 0.4787]
# 2026-04-16 18:37:25 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:37:25 [debug    ]   Standardized data std: 1.0036 (should be ~1)
# 2026-04-16 18:37:25 [debug    ] Fitting L/S model
# 2026-04-16 18:37:25 [debug    ] L/S Model estimates:
# 2026-04-16 18:37:25 [debug    ]   Gamma hat shape: (8, 68)
# 2026-04-16 18:37:25 [debug    ]   Gamma hat range: [-0.2719, 0.2311]
# 2026-04-16 18:37:25 [debug    ]   Site 0 delta range: [0.7041, 1.4152]
# 2026-04-16 18:37:25 [debug    ]   Site 1 delta range: [0.6168, 1.2738]
# 2026-04-16 18:37:25 [debug    ]   Site 2 delta range: [0.7613, 1.2790]
# 2026-04-16 18:37:25 [debug    ]   Site 3 delta range: [0.6940, 1.3520]
# 2026-04-16 18:37:25 [debug    ]   Site 4 delta range: [0.7728, 1.2707]
# 2026-04-16 18:37:25 [debug    ]   Site 5 delta range: [0.6689, 1.2866]
# 2026-04-16 18:37:25 [debug    ]   Site 6 delta range: [0.7550, 1.2527]
# 2026-04-16 18:37:25 [debug    ]   Site 7 delta range: [0.6654, 1.2399]
# 2026-04-16 18:37:25 [debug    ] Finding priors
# 2026-04-16 18:37:25 [debug    ]   Gamma bar (mean location effect): [-0.01574326  0.00117241 -0.01156688  0.01303456  0.00155992 -0.00131986
#   0.00864478  0.00433077]
# 2026-04-16 18:37:25 [debug    ]   Tau^2 (variance of location effects): [0.00879426 0.00571798 0.00638334 0.00911007 0.00682202 0.00614394
#  0.00718981 0.00763316]
# 2026-04-16 18:37:25 [debug    ]   Mean tau^2: 0.007224 (higher = more heterogeneous effects)
# 2026-04-16 18:37:25 [debug    ] Finding parametric adjustments
# 2026-04-16 18:37:25 [debug    ] _iteration_solver converged in 4 iterations (change=0.000002)
# 2026-04-16 18:37:25 [debug    ] _iteration_solver converged in 4 iterations (change=0.000000)
# 2026-04-16 18:37:25 [debug    ] _iteration_solver converged in 4 iterations (change=0.000002)
# 2026-04-16 18:37:25 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:37:25 [debug    ] _iteration_solver converged in 4 iterations (change=0.000003)
# 2026-04-16 18:37:25 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:37:25 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:37:25 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:37:25 [debug    ] Transforming
# 2026-04-16 18:37:25 [debug    ] Making design matrix
# 2026-04-16 18:37:25 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:37:25 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:37:25 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:37:25 [debug    ] Standardizing data across features
# 2026-04-16 18:37:25 [debug    ] Standardization stats:
# 2026-04-16 18:37:25 [debug    ]   Grand mean range: [1.5774, 3.7007]
# 2026-04-16 18:37:25 [debug    ]   Pooled std range: [0.1476, 0.4787]
# 2026-04-16 18:37:25 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:37:25 [debug    ]   Standardized data std: 1.0036 (should be ~1)
# 2026-04-16 18:37:25 [debug    ] Harmonizing data
# 2026-04-16 18:37:25 [debug    ] Transforming
# 2026-04-16 18:37:25 [debug    ] Making design matrix
# 2026-04-16 18:37:25 [debug    ] Sites encoded: 100 samples x 8 sites
# 2026-04-16 18:37:25 [debug    ] Design matrix shape: (100, 8)
# 2026-04-16 18:37:25 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:37:25 [debug    ] Standardizing data across features
# 2026-04-16 18:37:25 [debug    ] Standardization stats:
# 2026-04-16 18:37:25 [debug    ]   Grand mean range: [1.5774, 3.7007]
# 2026-04-16 18:37:25 [debug    ]   Pooled std range: [0.1476, 0.4787]
# 2026-04-16 18:37:25 [debug    ]   Standardized data mean: -0.017655 (should be ~0)
# 2026-04-16 18:37:25 [debug    ]   Standardized data std: 1.0128 (should be ~1)
# 2026-04-16 18:37:25 [debug    ] Harmonizing data
# 2026-04-16 18:37:25 [debug    ] Fitting
# 2026-04-16 18:37:25 [debug    ] Making design matrix
# 2026-04-16 18:37:25 [debug    ] Fitted site encoder: 8 sites
# 2026-04-16 18:37:25 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:37:25 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:37:25 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:37:25 [debug    ] Final formula for smoothing: y ~ x0 + x1 + x2 + x3 + x4 + x5 + x6 + x7 - 1
# 2026-04-16 18:37:25 [debug    ] Standardizing data across features
# 2026-04-16 18:37:25 [info     ] Smoothing more than 10 variables may take several minutes of computation.
# 2026-04-16 18:37:38 [debug    ] Standardization stats:
# 2026-04-16 18:37:38 [debug    ]   Grand mean range: [1.5699, 3.7008]
# 2026-04-16 18:37:38 [debug    ]   Pooled std range: [0.1492, 0.4759]
# 2026-04-16 18:37:38 [debug    ]   Standardized data mean: -0.000000 (should be ~0)
# 2026-04-16 18:37:38 [debug    ]   Standardized data std: 1.0035 (should be ~1)
# 2026-04-16 18:37:38 [debug    ] Fitting L/S model
# 2026-04-16 18:37:38 [debug    ] L/S Model estimates:
# 2026-04-16 18:37:38 [debug    ]   Gamma hat shape: (8, 68)
# 2026-04-16 18:37:38 [debug    ]   Gamma hat range: [-0.2855, 0.2782]
# 2026-04-16 18:37:38 [debug    ]   Site 0 delta range: [0.6806, 1.3419]
# 2026-04-16 18:37:38 [debug    ]   Site 1 delta range: [0.6661, 1.2768]
# 2026-04-16 18:37:38 [debug    ]   Site 2 delta range: [0.7953, 1.2163]
# 2026-04-16 18:37:38 [debug    ]   Site 3 delta range: [0.7617, 1.2840]
# 2026-04-16 18:37:38 [debug    ]   Site 4 delta range: [0.7905, 1.3014]
# 2026-04-16 18:37:38 [debug    ]   Site 5 delta range: [0.5775, 1.2988]
# 2026-04-16 18:37:38 [debug    ]   Site 6 delta range: [0.7726, 1.2965]
# 2026-04-16 18:37:38 [debug    ]   Site 7 delta range: [0.7539, 1.2524]
# 2026-04-16 18:37:38 [debug    ] Finding priors
# 2026-04-16 18:37:38 [debug    ]   Gamma bar (mean location effect): [-0.01507896  0.00428522 -0.02139461  0.01835383  0.00925086  0.00338217
#   0.00512425 -0.00592358]
# 2026-04-16 18:37:38 [debug    ]   Tau^2 (variance of location effects): [0.00721276 0.00647286 0.00778438 0.00798726 0.00668791 0.00597907
#  0.00625999 0.00817517]
# 2026-04-16 18:37:38 [debug    ]   Mean tau^2: 0.007070 (higher = more heterogeneous effects)
# 2026-04-16 18:37:38 [debug    ] Finding parametric adjustments
# 2026-04-16 18:37:38 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:37:38 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:37:38 [debug    ] _iteration_solver converged in 4 iterations (change=0.000000)
# 2026-04-16 18:37:38 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:37:38 [debug    ] _iteration_solver converged in 4 iterations (change=0.000002)
# 2026-04-16 18:37:38 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:37:38 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:37:38 [debug    ] _iteration_solver converged in 4 iterations (change=0.000002)
# 2026-04-16 18:37:38 [debug    ] Transforming
# 2026-04-16 18:37:38 [debug    ] Making design matrix
# 2026-04-16 18:37:38 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:37:38 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:37:38 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:37:38 [debug    ] Standardizing data across features
# 2026-04-16 18:37:38 [debug    ] Standardization stats:
# 2026-04-16 18:37:38 [debug    ]   Grand mean range: [1.5699, 3.7008]
# 2026-04-16 18:37:38 [debug    ]   Pooled std range: [0.1492, 0.4759]
# 2026-04-16 18:37:38 [debug    ]   Standardized data mean: -0.000000 (should be ~0)
# 2026-04-16 18:37:38 [debug    ]   Standardized data std: 1.0035 (should be ~1)
# 2026-04-16 18:37:38 [debug    ] Harmonizing data
# 2026-04-16 18:37:38 [debug    ] Transforming
# 2026-04-16 18:37:38 [debug    ] Making design matrix
# 2026-04-16 18:37:38 [debug    ] Sites encoded: 100 samples x 8 sites
# 2026-04-16 18:37:38 [debug    ] Design matrix shape: (100, 8)
# 2026-04-16 18:37:38 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:37:38 [debug    ] Standardizing data across features
# 2026-04-16 18:37:38 [debug    ] Standardization stats:
# 2026-04-16 18:37:38 [debug    ]   Grand mean range: [1.5699, 3.7008]
# 2026-04-16 18:37:38 [debug    ]   Pooled std range: [0.1492, 0.4759]
# 2026-04-16 18:37:38 [debug    ]   Standardized data mean: 0.014483 (should be ~0)
# 2026-04-16 18:37:38 [debug    ]   Standardized data std: 1.0193 (should be ~1)
# 2026-04-16 18:37:38 [debug    ] Harmonizing data
# 2026-04-16 18:37:38 [debug    ] Fitting
# 2026-04-16 18:37:38 [debug    ] Making design matrix
# 2026-04-16 18:37:38 [debug    ] Fitted site encoder: 8 sites
# 2026-04-16 18:37:38 [debug    ] Sites encoded: 900 samples x 8 sites
# 2026-04-16 18:37:38 [debug    ] Design matrix shape: (900, 8)
# 2026-04-16 18:37:38 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:37:38 [debug    ] Final formula for smoothing: y ~ x0 + x1 + x2 + x3 + x4 + x5 + x6 + x7 - 1
# 2026-04-16 18:37:38 [debug    ] Standardizing data across features
# 2026-04-16 18:37:38 [info     ] Smoothing more than 10 variables may take several minutes of computation.
# 2026-04-16 18:37:51 [debug    ] Standardization stats:
# 2026-04-16 18:37:51 [debug    ]   Grand mean range: [1.5702, 3.7112]
# 2026-04-16 18:37:51 [debug    ]   Pooled std range: [0.1495, 0.4710]
# 2026-04-16 18:37:51 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:37:51 [debug    ]   Standardized data std: 1.0038 (should be ~1)
# 2026-04-16 18:37:51 [debug    ] Fitting L/S model
# 2026-04-16 18:37:51 [debug    ] L/S Model estimates:
# 2026-04-16 18:37:51 [debug    ]   Gamma hat shape: (8, 68)
# 2026-04-16 18:37:51 [debug    ]   Gamma hat range: [-0.2527, 0.2963]
# 2026-04-16 18:37:51 [debug    ]   Site 0 delta range: [0.6729, 1.3819]
# 2026-04-16 18:37:51 [debug    ]   Site 1 delta range: [0.6392, 1.3465]
# 2026-04-16 18:37:51 [debug    ]   Site 2 delta range: [0.7782, 1.2796]
# 2026-04-16 18:37:51 [debug    ]   Site 3 delta range: [0.7441, 1.3889]
# 2026-04-16 18:37:51 [debug    ]   Site 4 delta range: [0.8227, 1.2913]
# 2026-04-16 18:37:51 [debug    ]   Site 5 delta range: [0.6058, 1.3013]
# 2026-04-16 18:37:51 [debug    ]   Site 6 delta range: [0.7736, 1.2509]
# 2026-04-16 18:37:51 [debug    ]   Site 7 delta range: [0.7375, 1.2228]
# 2026-04-16 18:37:51 [debug    ] Finding priors
# 2026-04-16 18:37:51 [debug    ]   Gamma bar (mean location effect): [-0.01932831  0.00289674 -0.01154277  0.01335068  0.00518147  0.00198318
#   0.00182107  0.00573561]
# 2026-04-16 18:37:51 [debug    ]   Tau^2 (variance of location effects): [0.00720212 0.00677159 0.00768511 0.00902619 0.0077673  0.00657026
#  0.00712216 0.00840048]
# 2026-04-16 18:37:51 [debug    ]   Mean tau^2: 0.007568 (higher = more heterogeneous effects)
# 2026-04-16 18:37:51 [debug    ] Finding parametric adjustments
# 2026-04-16 18:37:51 [debug    ] _iteration_solver converged in 4 iterations (change=0.000002)
# 2026-04-16 18:37:51 [debug    ] _iteration_solver converged in 3 iterations (change=0.000082)
# 2026-04-16 18:37:51 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:37:51 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:37:51 [debug    ] _iteration_solver converged in 4 iterations (change=0.000006)
# 2026-04-16 18:37:51 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:37:51 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:37:51 [debug    ] _iteration_solver converged in 4 iterations (change=0.000002)
# 2026-04-16 18:37:51 [debug    ] Transforming
# 2026-04-16 18:37:51 [debug    ] Making design matrix
# 2026-04-16 18:37:51 [debug    ] Sites encoded: 900 samples x 8 sites
# 2026-04-16 18:37:51 [debug    ] Design matrix shape: (900, 8)
# 2026-04-16 18:37:51 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:37:51 [debug    ] Standardizing data across features
# 2026-04-16 18:37:51 [debug    ] Standardization stats:
# 2026-04-16 18:37:51 [debug    ]   Grand mean range: [1.5702, 3.7112]
# 2026-04-16 18:37:51 [debug    ]   Pooled std range: [0.1495, 0.4710]
# 2026-04-16 18:37:51 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:37:51 [debug    ]   Standardized data std: 1.0038 (should be ~1)
# 2026-04-16 18:37:51 [debug    ] Harmonizing data
# 2026-04-16 18:37:51 [debug    ] Transforming
# 2026-04-16 18:37:51 [debug    ] Making design matrix
# 2026-04-16 18:37:51 [debug    ] Sites encoded: 101 samples x 8 sites
# 2026-04-16 18:37:51 [debug    ] Design matrix shape: (101, 8)
# 2026-04-16 18:37:51 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:37:51 [debug    ] Standardizing data across features
# 2026-04-16 18:37:51 [debug    ] Standardization stats:
# 2026-04-16 18:37:51 [debug    ]   Grand mean range: [1.5702, 3.7112]
# 2026-04-16 18:37:51 [debug    ]   Pooled std range: [0.1495, 0.4710]
# 2026-04-16 18:37:51 [debug    ]   Standardized data mean: 0.023707 (should be ~0)
# 2026-04-16 18:37:51 [debug    ]   Standardized data std: 1.0089 (should be ~1)
# 2026-04-16 18:37:51 [debug    ] Harmonizing data
# 2026-04-16 18:37:51 [debug    ] Fitting
# 2026-04-16 18:37:51 [debug    ] Making design matrix
# 2026-04-16 18:37:51 [debug    ] Fitted site encoder: 8 sites
# 2026-04-16 18:37:51 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:37:51 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:37:51 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:37:51 [debug    ] Final formula for smoothing: y ~ x0 + x1 + x2 + x3 + x4 + x5 + x6 + x7 - 1
# 2026-04-16 18:37:51 [debug    ] Standardizing data across features
# 2026-04-16 18:37:51 [info     ] Smoothing more than 10 variables may take several minutes of computation.
# 2026-04-16 18:38:05 [debug    ] Standardization stats:
# 2026-04-16 18:38:05 [debug    ]   Grand mean range: [1.5705, 3.6925]
# 2026-04-16 18:38:05 [debug    ]   Pooled std range: [0.1490, 0.4808]
# 2026-04-16 18:38:05 [debug    ]   Standardized data mean: -0.000000 (should be ~0)
# 2026-04-16 18:38:05 [debug    ]   Standardized data std: 1.0034 (should be ~1)
# 2026-04-16 18:38:05 [debug    ] Fitting L/S model
# 2026-04-16 18:38:05 [debug    ] L/S Model estimates:
# 2026-04-16 18:38:05 [debug    ]   Gamma hat shape: (8, 68)
# 2026-04-16 18:38:05 [debug    ]   Gamma hat range: [-0.2397, 0.2674]
# 2026-04-16 18:38:05 [debug    ]   Site 0 delta range: [0.7509, 1.3157]
# 2026-04-16 18:38:05 [debug    ]   Site 1 delta range: [0.6766, 1.3283]
# 2026-04-16 18:38:05 [debug    ]   Site 2 delta range: [0.7865, 1.3026]
# 2026-04-16 18:38:05 [debug    ]   Site 3 delta range: [0.7615, 1.3012]
# 2026-04-16 18:38:05 [debug    ]   Site 4 delta range: [0.7533, 1.2931]
# 2026-04-16 18:38:05 [debug    ]   Site 5 delta range: [0.6702, 1.2115]
# 2026-04-16 18:38:05 [debug    ]   Site 6 delta range: [0.7112, 1.3074]
# 2026-04-16 18:38:05 [debug    ]   Site 7 delta range: [0.7820, 1.2309]
# 2026-04-16 18:38:05 [debug    ] Finding priors
# 2026-04-16 18:38:05 [debug    ]   Gamma bar (mean location effect): [-0.01180662  0.00975777 -0.01725904  0.01043669  0.00254762 -0.00486196
#   0.00884739  0.00275608]
# 2026-04-16 18:38:05 [debug    ]   Tau^2 (variance of location effects): [0.00674519 0.00617294 0.0062815  0.0082282  0.00756834 0.00517408
#  0.00694226 0.00761005]
# 2026-04-16 18:38:05 [debug    ]   Mean tau^2: 0.006840 (higher = more heterogeneous effects)
# 2026-04-16 18:38:05 [debug    ] Finding parametric adjustments
# 2026-04-16 18:38:05 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:05 [debug    ] _iteration_solver converged in 4 iterations (change=0.000000)
# 2026-04-16 18:38:05 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:05 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:05 [debug    ] _iteration_solver converged in 4 iterations (change=0.000002)
# 2026-04-16 18:38:05 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:05 [debug    ] _iteration_solver converged in 4 iterations (change=0.000000)
# 2026-04-16 18:38:05 [debug    ] _iteration_solver converged in 4 iterations (change=0.000002)
# 2026-04-16 18:38:05 [debug    ] Transforming
# 2026-04-16 18:38:05 [debug    ] Making design matrix
# 2026-04-16 18:38:05 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:38:05 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:38:05 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:38:05 [debug    ] Standardizing data across features
# 2026-04-16 18:38:05 [debug    ] Standardization stats:
# 2026-04-16 18:38:05 [debug    ]   Grand mean range: [1.5705, 3.6925]
# 2026-04-16 18:38:05 [debug    ]   Pooled std range: [0.1490, 0.4808]
# 2026-04-16 18:38:05 [debug    ]   Standardized data mean: -0.000000 (should be ~0)
# 2026-04-16 18:38:05 [debug    ]   Standardized data std: 1.0034 (should be ~1)
# 2026-04-16 18:38:05 [debug    ] Harmonizing data
# 2026-04-16 18:38:05 [debug    ] Transforming
# 2026-04-16 18:38:05 [debug    ] Making design matrix
# 2026-04-16 18:38:05 [debug    ] Sites encoded: 100 samples x 8 sites
# 2026-04-16 18:38:05 [debug    ] Design matrix shape: (100, 8)
# 2026-04-16 18:38:05 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:38:05 [debug    ] Standardizing data across features
# 2026-04-16 18:38:05 [debug    ] Standardization stats:
# 2026-04-16 18:38:05 [debug    ]   Grand mean range: [1.5705, 3.6925]
# 2026-04-16 18:38:05 [debug    ]   Pooled std range: [0.1490, 0.4808]
# 2026-04-16 18:38:05 [debug    ]   Standardized data mean: 0.009994 (should be ~0)
# 2026-04-16 18:38:05 [debug    ]   Standardized data std: 1.0063 (should be ~1)
# 2026-04-16 18:38:05 [debug    ] Harmonizing data
# 2026-04-16 18:38:05 [debug    ] Fitting
# 2026-04-16 18:38:05 [debug    ] Making design matrix
# 2026-04-16 18:38:05 [debug    ] Fitted site encoder: 8 sites
# 2026-04-16 18:38:05 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:38:05 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:38:05 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:38:05 [debug    ] Final formula for smoothing: y ~ x0 + x1 + x2 + x3 + x4 + x5 + x6 + x7 - 1
# 2026-04-16 18:38:05 [debug    ] Standardizing data across features
# 2026-04-16 18:38:05 [info     ] Smoothing more than 10 variables may take several minutes of computation.
# 2026-04-16 18:38:18 [debug    ] Standardization stats:
# 2026-04-16 18:38:18 [debug    ]   Grand mean range: [1.5726, 3.7110]
# 2026-04-16 18:38:18 [debug    ]   Pooled std range: [0.1502, 0.4722]
# 2026-04-16 18:38:18 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:38:18 [debug    ]   Standardized data std: 1.0036 (should be ~1)
# 2026-04-16 18:38:18 [debug    ] Fitting L/S model
# 2026-04-16 18:38:18 [debug    ] L/S Model estimates:
# 2026-04-16 18:38:18 [debug    ]   Gamma hat shape: (8, 68)
# 2026-04-16 18:38:18 [debug    ]   Gamma hat range: [-0.2758, 0.2758]
# 2026-04-16 18:38:18 [debug    ]   Site 0 delta range: [0.6558, 1.3236]
# 2026-04-16 18:38:18 [debug    ]   Site 1 delta range: [0.6941, 1.2853]
# 2026-04-16 18:38:18 [debug    ]   Site 2 delta range: [0.7688, 1.2317]
# 2026-04-16 18:38:18 [debug    ]   Site 3 delta range: [0.7471, 1.3842]
# 2026-04-16 18:38:18 [debug    ]   Site 4 delta range: [0.7554, 1.2861]
# 2026-04-16 18:38:18 [debug    ]   Site 5 delta range: [0.6318, 1.2670]
# 2026-04-16 18:38:18 [debug    ]   Site 6 delta range: [0.7176, 1.2418]
# 2026-04-16 18:38:18 [debug    ]   Site 7 delta range: [0.8050, 1.2529]
# 2026-04-16 18:38:18 [debug    ] Finding priors
# 2026-04-16 18:38:18 [debug    ]   Gamma bar (mean location effect): [-0.01560911  0.00464162 -0.01857525  0.01527922  0.00625615  0.00968452
#  -0.0024627   0.00169337]
# 2026-04-16 18:38:18 [debug    ]   Tau^2 (variance of location effects): [0.00703363 0.00655019 0.00616736 0.00922893 0.00742539 0.00549629
#  0.0092047  0.00704741]
# 2026-04-16 18:38:18 [debug    ]   Mean tau^2: 0.007269 (higher = more heterogeneous effects)
# 2026-04-16 18:38:18 [debug    ] Finding parametric adjustments
# 2026-04-16 18:38:18 [debug    ] _iteration_solver converged in 4 iterations (change=0.000002)
# 2026-04-16 18:38:18 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:18 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:18 [debug    ] _iteration_solver converged in 4 iterations (change=0.000002)
# 2026-04-16 18:38:18 [debug    ] _iteration_solver converged in 4 iterations (change=0.000002)
# 2026-04-16 18:38:18 [debug    ] _iteration_solver converged in 4 iterations (change=0.000002)
# 2026-04-16 18:38:18 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:18 [debug    ] _iteration_solver converged in 4 iterations (change=0.000000)
# 2026-04-16 18:38:18 [debug    ] Transforming
# 2026-04-16 18:38:18 [debug    ] Making design matrix
# 2026-04-16 18:38:18 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:38:18 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:38:18 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:38:18 [debug    ] Standardizing data across features
# 2026-04-16 18:38:18 [debug    ] Standardization stats:
# 2026-04-16 18:38:18 [debug    ]   Grand mean range: [1.5726, 3.7110]
# 2026-04-16 18:38:18 [debug    ]   Pooled std range: [0.1502, 0.4722]
# 2026-04-16 18:38:18 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:38:18 [debug    ]   Standardized data std: 1.0036 (should be ~1)
# 2026-04-16 18:38:18 [debug    ] Harmonizing data
# 2026-04-16 18:38:18 [debug    ] Transforming
# 2026-04-16 18:38:18 [debug    ] Making design matrix
# 2026-04-16 18:38:18 [debug    ] Sites encoded: 100 samples x 8 sites
# 2026-04-16 18:38:18 [debug    ] Design matrix shape: (100, 8)
# 2026-04-16 18:38:18 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:38:18 [debug    ] Standardizing data across features
# 2026-04-16 18:38:18 [debug    ] Standardization stats:
# 2026-04-16 18:38:18 [debug    ]   Grand mean range: [1.5726, 3.7110]
# 2026-04-16 18:38:18 [debug    ]   Pooled std range: [0.1502, 0.4722]
# 2026-04-16 18:38:18 [debug    ]   Standardized data mean: 0.002933 (should be ~0)
# 2026-04-16 18:38:18 [debug    ]   Standardized data std: 1.0075 (should be ~1)
# 2026-04-16 18:38:18 [debug    ] Harmonizing data
# 2026-04-16 18:38:18 [debug    ] Fitting
# 2026-04-16 18:38:18 [debug    ] Making design matrix
# 2026-04-16 18:38:18 [debug    ] Fitted site encoder: 8 sites
# 2026-04-16 18:38:18 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:38:18 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:38:18 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:38:18 [debug    ] Final formula for smoothing: y ~ x0 + x1 + x2 + x3 + x4 + x5 + x6 + x7 - 1
# 2026-04-16 18:38:18 [debug    ] Standardizing data across features
# 2026-04-16 18:38:18 [info     ] Smoothing more than 10 variables may take several minutes of computation.
# 2026-04-16 18:38:31 [debug    ] Standardization stats:
# 2026-04-16 18:38:31 [debug    ]   Grand mean range: [1.5737, 3.6998]
# 2026-04-16 18:38:31 [debug    ]   Pooled std range: [0.1509, 0.4770]
# 2026-04-16 18:38:31 [debug    ]   Standardized data mean: -0.000000 (should be ~0)
# 2026-04-16 18:38:31 [debug    ]   Standardized data std: 1.0037 (should be ~1)
# 2026-04-16 18:38:31 [debug    ] Fitting L/S model
# 2026-04-16 18:38:31 [debug    ] L/S Model estimates:
# 2026-04-16 18:38:31 [debug    ]   Gamma hat shape: (8, 68)
# 2026-04-16 18:38:31 [debug    ]   Gamma hat range: [-0.2494, 0.2728]
# 2026-04-16 18:38:31 [debug    ]   Site 0 delta range: [0.7516, 1.3566]
# 2026-04-16 18:38:31 [debug    ]   Site 1 delta range: [0.6805, 1.3073]
# 2026-04-16 18:38:31 [debug    ]   Site 2 delta range: [0.7826, 1.2942]
# 2026-04-16 18:38:31 [debug    ]   Site 3 delta range: [0.7345, 1.3829]
# 2026-04-16 18:38:31 [debug    ]   Site 4 delta range: [0.7987, 1.3366]
# 2026-04-16 18:38:31 [debug    ]   Site 5 delta range: [0.6378, 1.2192]
# 2026-04-16 18:38:31 [debug    ]   Site 6 delta range: [0.7350, 1.2642]
# 2026-04-16 18:38:31 [debug    ]   Site 7 delta range: [0.7852, 1.2603]
# 2026-04-16 18:38:31 [debug    ] Finding priors
# 2026-04-16 18:38:31 [debug    ]   Gamma bar (mean location effect): [-0.01380417  0.00017552 -0.01718058  0.0133509   0.00866288  0.00837695
#   0.00396152 -0.0037369 ]
# 2026-04-16 18:38:31 [debug    ]   Tau^2 (variance of location effects): [0.00791218 0.00772616 0.00714983 0.00820165 0.0073684  0.00632856
#  0.00757129 0.00766647]
# 2026-04-16 18:38:31 [debug    ]   Mean tau^2: 0.007491 (higher = more heterogeneous effects)
# 2026-04-16 18:38:31 [debug    ] Finding parametric adjustments
# 2026-04-16 18:38:31 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:31 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:31 [debug    ] _iteration_solver converged in 4 iterations (change=0.000002)
# 2026-04-16 18:38:31 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:31 [debug    ] _iteration_solver converged in 4 iterations (change=0.000003)
# 2026-04-16 18:38:31 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:31 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:31 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:31 [debug    ] Transforming
# 2026-04-16 18:38:31 [debug    ] Making design matrix
# 2026-04-16 18:38:31 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:38:31 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:38:31 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:38:31 [debug    ] Standardizing data across features
# 2026-04-16 18:38:31 [debug    ] Standardization stats:
# 2026-04-16 18:38:31 [debug    ]   Grand mean range: [1.5737, 3.6998]
# 2026-04-16 18:38:31 [debug    ]   Pooled std range: [0.1509, 0.4770]
# 2026-04-16 18:38:31 [debug    ]   Standardized data mean: -0.000000 (should be ~0)
# 2026-04-16 18:38:31 [debug    ]   Standardized data std: 1.0037 (should be ~1)
# 2026-04-16 18:38:31 [debug    ] Harmonizing data
# 2026-04-16 18:38:31 [debug    ] Transforming
# 2026-04-16 18:38:31 [debug    ] Making design matrix
# 2026-04-16 18:38:31 [debug    ] Sites encoded: 100 samples x 8 sites
# 2026-04-16 18:38:31 [debug    ] Design matrix shape: (100, 8)
# 2026-04-16 18:38:31 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:38:31 [debug    ] Standardizing data across features
# 2026-04-16 18:38:31 [debug    ] Standardization stats:
# 2026-04-16 18:38:31 [debug    ]   Grand mean range: [1.5737, 3.6998]
# 2026-04-16 18:38:31 [debug    ]   Pooled std range: [0.1509, 0.4770]
# 2026-04-16 18:38:31 [debug    ]   Standardized data mean: 0.002344 (should be ~0)
# 2026-04-16 18:38:31 [debug    ]   Standardized data std: 0.9977 (should be ~1)
# 2026-04-16 18:38:31 [debug    ] Harmonizing data
# 2026-04-16 18:38:31 [debug    ] Fitting
# 2026-04-16 18:38:31 [debug    ] Making design matrix
# 2026-04-16 18:38:31 [debug    ] Fitted site encoder: 8 sites
# 2026-04-16 18:38:31 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:38:31 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:38:31 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:38:31 [debug    ] Final formula for smoothing: y ~ x0 + x1 + x2 + x3 + x4 + x5 + x6 + x7 - 1
# 2026-04-16 18:38:31 [debug    ] Standardizing data across features
# 2026-04-16 18:38:31 [info     ] Smoothing more than 10 variables may take several minutes of computation.
# 2026-04-16 18:38:44 [debug    ] Standardization stats:
# 2026-04-16 18:38:44 [debug    ]   Grand mean range: [1.5737, 3.7058]
# 2026-04-16 18:38:44 [debug    ]   Pooled std range: [0.1496, 0.4777]
# 2026-04-16 18:38:44 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:38:44 [debug    ]   Standardized data std: 1.0040 (should be ~1)
# 2026-04-16 18:38:44 [debug    ] Fitting L/S model
# 2026-04-16 18:38:44 [debug    ] L/S Model estimates:
# 2026-04-16 18:38:44 [debug    ]   Gamma hat shape: (8, 68)
# 2026-04-16 18:38:44 [debug    ]   Gamma hat range: [-0.2979, 0.2779]
# 2026-04-16 18:38:44 [debug    ]   Site 0 delta range: [0.7523, 1.4846]
# 2026-04-16 18:38:44 [debug    ]   Site 1 delta range: [0.6408, 1.3290]
# 2026-04-16 18:38:44 [debug    ]   Site 2 delta range: [0.7302, 1.2880]
# 2026-04-16 18:38:44 [debug    ]   Site 3 delta range: [0.7606, 1.2586]
# 2026-04-16 18:38:44 [debug    ]   Site 4 delta range: [0.7853, 1.2522]
# 2026-04-16 18:38:44 [debug    ]   Site 5 delta range: [0.6279, 1.1860]
# 2026-04-16 18:38:44 [debug    ]   Site 6 delta range: [0.7531, 1.2856]
# 2026-04-16 18:38:44 [debug    ]   Site 7 delta range: [0.8107, 1.2292]
# 2026-04-16 18:38:44 [debug    ] Finding priors
# 2026-04-16 18:38:44 [debug    ]   Gamma bar (mean location effect): [-0.01265913  0.00361947 -0.02232483  0.01106586  0.00780619  0.00622692
#   0.00191267  0.00239097]
# 2026-04-16 18:38:44 [debug    ]   Tau^2 (variance of location effects): [0.00875978 0.00654954 0.0091134  0.0099163  0.00714448 0.00630896
#  0.00795052 0.00794418]
# 2026-04-16 18:38:44 [debug    ]   Mean tau^2: 0.007961 (higher = more heterogeneous effects)
# 2026-04-16 18:38:44 [debug    ] Finding parametric adjustments
# 2026-04-16 18:38:44 [debug    ] _iteration_solver converged in 4 iterations (change=0.000002)
# 2026-04-16 18:38:44 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:44 [debug    ] _iteration_solver converged in 4 iterations (change=0.000000)
# 2026-04-16 18:38:44 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:44 [debug    ] _iteration_solver converged in 4 iterations (change=0.000004)
# 2026-04-16 18:38:44 [debug    ] _iteration_solver converged in 4 iterations (change=0.000000)
# 2026-04-16 18:38:44 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:44 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:44 [debug    ] Transforming
# 2026-04-16 18:38:44 [debug    ] Making design matrix
# 2026-04-16 18:38:44 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:38:44 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:38:44 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:38:44 [debug    ] Standardizing data across features
# 2026-04-16 18:38:44 [debug    ] Standardization stats:
# 2026-04-16 18:38:44 [debug    ]   Grand mean range: [1.5737, 3.7058]
# 2026-04-16 18:38:44 [debug    ]   Pooled std range: [0.1496, 0.4777]
# 2026-04-16 18:38:44 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:38:44 [debug    ]   Standardized data std: 1.0040 (should be ~1)
# 2026-04-16 18:38:44 [debug    ] Harmonizing data
# 2026-04-16 18:38:44 [debug    ] Transforming
# 2026-04-16 18:38:44 [debug    ] Making design matrix
# 2026-04-16 18:38:44 [debug    ] Sites encoded: 100 samples x 8 sites
# 2026-04-16 18:38:44 [debug    ] Design matrix shape: (100, 8)
# 2026-04-16 18:38:44 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:38:44 [debug    ] Standardizing data across features
# 2026-04-16 18:38:44 [debug    ] Standardization stats:
# 2026-04-16 18:38:44 [debug    ]   Grand mean range: [1.5737, 3.7058]
# 2026-04-16 18:38:44 [debug    ]   Pooled std range: [0.1496, 0.4777]
# 2026-04-16 18:38:44 [debug    ]   Standardized data mean: 0.008408 (should be ~0)
# 2026-04-16 18:38:44 [debug    ]   Standardized data std: 1.0060 (should be ~1)
# 2026-04-16 18:38:44 [debug    ] Harmonizing data
# 2026-04-16 18:38:44 [debug    ] Fitting
# 2026-04-16 18:38:44 [debug    ] Making design matrix
# 2026-04-16 18:38:44 [debug    ] Fitted site encoder: 8 sites
# 2026-04-16 18:38:44 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:38:44 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:38:44 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:38:44 [debug    ] Final formula for smoothing: y ~ x0 + x1 + x2 + x3 + x4 + x5 + x6 + x7 - 1
# 2026-04-16 18:38:44 [debug    ] Standardizing data across features
# 2026-04-16 18:38:44 [info     ] Smoothing more than 10 variables may take several minutes of computation.
# 2026-04-16 18:38:57 [debug    ] Standardization stats:
# 2026-04-16 18:38:57 [debug    ]   Grand mean range: [1.5733, 3.7159]
# 2026-04-16 18:38:57 [debug    ]   Pooled std range: [0.1502, 0.4738]
# 2026-04-16 18:38:57 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:38:57 [debug    ]   Standardized data std: 1.0035 (should be ~1)
# 2026-04-16 18:38:57 [debug    ] Fitting L/S model
# 2026-04-16 18:38:57 [debug    ] L/S Model estimates:
# 2026-04-16 18:38:57 [debug    ]   Gamma hat shape: (8, 68)
# 2026-04-16 18:38:57 [debug    ]   Gamma hat range: [-0.2998, 0.2548]
# 2026-04-16 18:38:57 [debug    ]   Site 0 delta range: [0.7024, 1.4353]
# 2026-04-16 18:38:57 [debug    ]   Site 1 delta range: [0.6829, 1.2540]
# 2026-04-16 18:38:57 [debug    ]   Site 2 delta range: [0.7680, 1.2712]
# 2026-04-16 18:38:57 [debug    ]   Site 3 delta range: [0.7701, 1.3246]
# 2026-04-16 18:38:57 [debug    ]   Site 4 delta range: [0.7866, 1.3538]
# 2026-04-16 18:38:57 [debug    ]   Site 5 delta range: [0.6370, 1.1994]
# 2026-04-16 18:38:57 [debug    ]   Site 6 delta range: [0.7428, 1.2669]
# 2026-04-16 18:38:57 [debug    ]   Site 7 delta range: [0.7863, 1.2495]
# 2026-04-16 18:38:57 [debug    ] Finding priors
# 2026-04-16 18:38:57 [debug    ]   Gamma bar (mean location effect): [-0.02679242  0.00339003 -0.01105245  0.01868963  0.00389844  0.00403941
#   0.00314159  0.00499776]
# 2026-04-16 18:38:57 [debug    ]   Tau^2 (variance of location effects): [0.00742052 0.00601273 0.00618246 0.00934487 0.00708522 0.00585039
#  0.00612373 0.00797686]
# 2026-04-16 18:38:57 [debug    ]   Mean tau^2: 0.007000 (higher = more heterogeneous effects)
# 2026-04-16 18:38:57 [debug    ] Finding parametric adjustments
# 2026-04-16 18:38:57 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:57 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:57 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:57 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:57 [debug    ] _iteration_solver converged in 4 iterations (change=0.000004)
# 2026-04-16 18:38:57 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:57 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:57 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:38:57 [debug    ] Transforming
# 2026-04-16 18:38:57 [debug    ] Making design matrix
# 2026-04-16 18:38:57 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:38:57 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:38:57 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:38:57 [debug    ] Standardizing data across features
# 2026-04-16 18:38:57 [debug    ] Standardization stats:
# 2026-04-16 18:38:57 [debug    ]   Grand mean range: [1.5733, 3.7159]
# 2026-04-16 18:38:57 [debug    ]   Pooled std range: [0.1502, 0.4738]
# 2026-04-16 18:38:57 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:38:57 [debug    ]   Standardized data std: 1.0035 (should be ~1)
# 2026-04-16 18:38:57 [debug    ] Harmonizing data
# 2026-04-16 18:38:57 [debug    ] Transforming
# 2026-04-16 18:38:57 [debug    ] Making design matrix
# 2026-04-16 18:38:57 [debug    ] Sites encoded: 100 samples x 8 sites
# 2026-04-16 18:38:57 [debug    ] Design matrix shape: (100, 8)
# 2026-04-16 18:38:57 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:38:57 [debug    ] Standardizing data across features
# 2026-04-16 18:38:57 [debug    ] Standardization stats:
# 2026-04-16 18:38:57 [debug    ]   Grand mean range: [1.5733, 3.7159]
# 2026-04-16 18:38:57 [debug    ]   Pooled std range: [0.1502, 0.4738]
# 2026-04-16 18:38:57 [debug    ]   Standardized data mean: -0.020215 (should be ~0)
# 2026-04-16 18:38:57 [debug    ]   Standardized data std: 1.0093 (should be ~1)
# 2026-04-16 18:38:57 [debug    ] Harmonizing data
# 2026-04-16 18:38:57 [debug    ] Fitting
# 2026-04-16 18:38:57 [debug    ] Making design matrix
# 2026-04-16 18:38:57 [debug    ] Fitted site encoder: 8 sites
# 2026-04-16 18:38:57 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:38:57 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:38:57 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:38:57 [debug    ] Final formula for smoothing: y ~ x0 + x1 + x2 + x3 + x4 + x5 + x6 + x7 - 1
# 2026-04-16 18:38:57 [debug    ] Standardizing data across features
# 2026-04-16 18:38:57 [info     ] Smoothing more than 10 variables may take several minutes of computation.
# 2026-04-16 18:39:11 [debug    ] Standardization stats:
# 2026-04-16 18:39:11 [debug    ]   Grand mean range: [1.5743, 3.6979]
# 2026-04-16 18:39:11 [debug    ]   Pooled std range: [0.1498, 0.4722]
# 2026-04-16 18:39:11 [debug    ]   Standardized data mean: -0.000000 (should be ~0)
# 2026-04-16 18:39:11 [debug    ]   Standardized data std: 1.0037 (should be ~1)
# 2026-04-16 18:39:11 [debug    ] Fitting L/S model
# 2026-04-16 18:39:11 [debug    ] L/S Model estimates:
# 2026-04-16 18:39:11 [debug    ]   Gamma hat shape: (8, 68)
# 2026-04-16 18:39:11 [debug    ]   Gamma hat range: [-0.2615, 0.2908]
# 2026-04-16 18:39:11 [debug    ]   Site 0 delta range: [0.7403, 1.4124]
# 2026-04-16 18:39:11 [debug    ]   Site 1 delta range: [0.6471, 1.3263]
# 2026-04-16 18:39:11 [debug    ]   Site 2 delta range: [0.7777, 1.2616]
# 2026-04-16 18:39:11 [debug    ]   Site 3 delta range: [0.7191, 1.3410]
# 2026-04-16 18:39:11 [debug    ]   Site 4 delta range: [0.7849, 1.2516]
# 2026-04-16 18:39:11 [debug    ]   Site 5 delta range: [0.6026, 1.2551]
# 2026-04-16 18:39:11 [debug    ]   Site 6 delta range: [0.7704, 1.2372]
# 2026-04-16 18:39:11 [debug    ]   Site 7 delta range: [0.7580, 1.2386]
# 2026-04-16 18:39:11 [debug    ] Finding priors
# 2026-04-16 18:39:11 [debug    ]   Gamma bar (mean location effect): [-0.01661906  0.00203254 -0.0233858   0.01917416  0.01080229  0.0071435
#   0.00223006 -0.00303764]
# 2026-04-16 18:39:11 [debug    ]   Tau^2 (variance of location effects): [0.00709959 0.00668669 0.00700987 0.00940684 0.00728525 0.00639797
#  0.00686057 0.00802837]
# 2026-04-16 18:39:11 [debug    ]   Mean tau^2: 0.007347 (higher = more heterogeneous effects)
# 2026-04-16 18:39:11 [debug    ] Finding parametric adjustments
# 2026-04-16 18:39:11 [debug    ] _iteration_solver converged in 4 iterations (change=0.000004)
# 2026-04-16 18:39:11 [debug    ] _iteration_solver converged in 4 iterations (change=0.000000)
# 2026-04-16 18:39:11 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:39:11 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:39:11 [debug    ] _iteration_solver converged in 4 iterations (change=0.000003)
# 2026-04-16 18:39:11 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:39:11 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:39:11 [debug    ] _iteration_solver converged in 4 iterations (change=0.000002)
# 2026-04-16 18:39:11 [debug    ] Transforming
# 2026-04-16 18:39:11 [debug    ] Making design matrix
# 2026-04-16 18:39:11 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:39:11 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:39:11 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:39:11 [debug    ] Standardizing data across features
# 2026-04-16 18:39:11 [debug    ] Standardization stats:
# 2026-04-16 18:39:11 [debug    ]   Grand mean range: [1.5743, 3.6979]
# 2026-04-16 18:39:11 [debug    ]   Pooled std range: [0.1498, 0.4722]
# 2026-04-16 18:39:11 [debug    ]   Standardized data mean: -0.000000 (should be ~0)
# 2026-04-16 18:39:11 [debug    ]   Standardized data std: 1.0037 (should be ~1)
# 2026-04-16 18:39:11 [debug    ] Harmonizing data
# 2026-04-16 18:39:11 [debug    ] Transforming
# 2026-04-16 18:39:11 [debug    ] Making design matrix
# 2026-04-16 18:39:11 [debug    ] Sites encoded: 100 samples x 8 sites
# 2026-04-16 18:39:11 [debug    ] Design matrix shape: (100, 8)
# 2026-04-16 18:39:11 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:39:11 [debug    ] Standardizing data across features
# 2026-04-16 18:39:11 [debug    ] Standardization stats:
# 2026-04-16 18:39:11 [debug    ]   Grand mean range: [1.5743, 3.6979]
# 2026-04-16 18:39:11 [debug    ]   Pooled std range: [0.1498, 0.4722]
# 2026-04-16 18:39:11 [debug    ]   Standardized data mean: -0.006430 (should be ~0)
# 2026-04-16 18:39:11 [debug    ]   Standardized data std: 1.0037 (should be ~1)
# 2026-04-16 18:39:11 [debug    ] Harmonizing data
# 2026-04-16 18:39:11 [debug    ] Fitting
# 2026-04-16 18:39:11 [debug    ] Making design matrix
# 2026-04-16 18:39:11 [debug    ] Fitted site encoder: 8 sites
# 2026-04-16 18:39:11 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:39:11 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:39:11 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:39:11 [debug    ] Final formula for smoothing: y ~ x0 + x1 + x2 + x3 + x4 + x5 + x6 + x7 - 1
# 2026-04-16 18:39:11 [debug    ] Standardizing data across features
# 2026-04-16 18:39:11 [info     ] Smoothing more than 10 variables may take several minutes of computation.
# 2026-04-16 18:39:24 [debug    ] Standardization stats:
# 2026-04-16 18:39:24 [debug    ]   Grand mean range: [1.5745, 3.6967]
# 2026-04-16 18:39:24 [debug    ]   Pooled std range: [0.1510, 0.4796]
# 2026-04-16 18:39:24 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:39:24 [debug    ]   Standardized data std: 1.0036 (should be ~1)
# 2026-04-16 18:39:24 [debug    ] Fitting L/S model
# 2026-04-16 18:39:24 [debug    ] L/S Model estimates:
# 2026-04-16 18:39:24 [debug    ]   Gamma hat shape: (8, 68)
# 2026-04-16 18:39:24 [debug    ]   Gamma hat range: [-0.2348, 0.2403]
# 2026-04-16 18:39:24 [debug    ]   Site 0 delta range: [0.7301, 1.3775]
# 2026-04-16 18:39:24 [debug    ]   Site 1 delta range: [0.6270, 1.2941]
# 2026-04-16 18:39:24 [debug    ]   Site 2 delta range: [0.7451, 1.2497]
# 2026-04-16 18:39:24 [debug    ]   Site 3 delta range: [0.7362, 1.3464]
# 2026-04-16 18:39:24 [debug    ]   Site 4 delta range: [0.7787, 1.3600]
# 2026-04-16 18:39:24 [debug    ]   Site 5 delta range: [0.6137, 1.2221]
# 2026-04-16 18:39:24 [debug    ]   Site 6 delta range: [0.6914, 1.3286]
# 2026-04-16 18:39:24 [debug    ]   Site 7 delta range: [0.7652, 1.2718]
# 2026-04-16 18:39:24 [debug    ] Finding priors
# 2026-04-16 18:39:24 [debug    ]   Gamma bar (mean location effect): [-0.01954303  0.00353679 -0.01397268  0.00941195  0.00539468  0.00456038
#   0.01322638 -0.00132736]
# 2026-04-16 18:39:24 [debug    ]   Tau^2 (variance of location effects): [0.00704561 0.00691051 0.00743761 0.00859995 0.00654032 0.00543424
#  0.00825727 0.0076124 ]
# 2026-04-16 18:39:24 [debug    ]   Mean tau^2: 0.007230 (higher = more heterogeneous effects)
# 2026-04-16 18:39:24 [debug    ] Finding parametric adjustments
# 2026-04-16 18:39:24 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:39:24 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:39:24 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:39:24 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:39:24 [debug    ] _iteration_solver converged in 4 iterations (change=0.000004)
# 2026-04-16 18:39:24 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:39:24 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:39:24 [debug    ] _iteration_solver converged in 4 iterations (change=0.000001)
# 2026-04-16 18:39:24 [debug    ] Transforming
# 2026-04-16 18:39:24 [debug    ] Making design matrix
# 2026-04-16 18:39:24 [debug    ] Sites encoded: 901 samples x 8 sites
# 2026-04-16 18:39:24 [debug    ] Design matrix shape: (901, 8)
# 2026-04-16 18:39:24 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:39:24 [debug    ] Standardizing data across features
# 2026-04-16 18:39:24 [debug    ] Standardization stats:
# 2026-04-16 18:39:24 [debug    ]   Grand mean range: [1.5745, 3.6967]
# 2026-04-16 18:39:24 [debug    ]   Pooled std range: [0.1510, 0.4796]
# 2026-04-16 18:39:24 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:39:24 [debug    ]   Standardized data std: 1.0036 (should be ~1)
# 2026-04-16 18:39:24 [debug    ] Harmonizing data
# 2026-04-16 18:39:24 [debug    ] Transforming
# 2026-04-16 18:39:24 [debug    ] Making design matrix
# 2026-04-16 18:39:24 [debug    ] Sites encoded: 100 samples x 8 sites
# 2026-04-16 18:39:24 [debug    ] Design matrix shape: (100, 8)
# 2026-04-16 18:39:24 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:39:24 [debug    ] Standardizing data across features
# 2026-04-16 18:39:24 [debug    ] Standardization stats:
# 2026-04-16 18:39:24 [debug    ]   Grand mean range: [1.5745, 3.6967]
# 2026-04-16 18:39:24 [debug    ]   Pooled std range: [0.1510, 0.4796]
# 2026-04-16 18:39:24 [debug    ]   Standardized data mean: -0.017226 (should be ~0)
# 2026-04-16 18:39:24 [debug    ]   Standardized data std: 0.9984 (should be ~1)
# ...
# 2026-04-16 18:51:01 [debug    ] Sites encoded: 860 samples x 8 sites
# 2026-04-16 18:51:01 [debug    ] Design matrix shape: (860, 8)
# 2026-04-16 18:51:01 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:51:01 [debug    ] Standardizing data across features
# 2026-04-16 18:51:01 [debug    ] Standardization stats:
# 2026-04-16 18:51:01 [debug    ]   Grand mean range: [584.8298, 7738.4889]
# 2026-04-16 18:51:01 [debug    ]   Pooled std range: [88.2344, 952.8407]
# 2026-04-16 18:51:01 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:51:01 [debug    ]   Standardized data std: 1.4747 (should be ~1)
# 2026-04-16 18:51:01 [debug    ] Harmonizing data
# 2026-04-16 18:51:01 [debug    ] Transforming
# 2026-04-16 18:51:01 [debug    ] Making design matrix
# 2026-04-16 18:51:01 [debug    ] Sites encoded: 96 samples x 8 sites
# 2026-04-16 18:51:01 [debug    ] Design matrix shape: (96, 8)
# 2026-04-16 18:51:01 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:51:01 [debug    ] Standardizing data across features
# 2026-04-16 18:51:01 [debug    ] Standardization stats:
# 2026-04-16 18:51:01 [debug    ]   Grand mean range: [584.8298, 7738.4889]
# 2026-04-16 18:51:01 [debug    ]   Pooled std range: [88.2344, 952.8407]
# 2026-04-16 18:51:01 [debug    ]   Standardized data mean: -0.081769 (should be ~0)
# 2026-04-16 18:51:01 [debug    ]   Standardized data std: 1.4166 (should be ~1)
# 2026-04-16 18:51:01 [debug    ] Harmonizing data
# 2026-04-16 18:51:01 [debug    ] Fitting
# 2026-04-16 18:51:01 [debug    ] Making design matrix
# 2026-04-16 18:51:01 [debug    ] Fitted site encoder: 8 sites
# 2026-04-16 18:51:01 [debug    ] Sites encoded: 860 samples x 8 sites
# 2026-04-16 18:51:01 [debug    ] Design matrix shape: (860, 8)
# 2026-04-16 18:51:01 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:51:01 [debug    ] Final formula for smoothing: y ~ x0 + x1 + x2 + x3 + x4 + x5 + x6 + x7 - 1
# 2026-04-16 18:51:01 [debug    ] Standardizing data across features
# 2026-04-16 18:51:01 [info     ] Smoothing more than 10 variables may take several minutes of computation.
# 2026-04-16 18:51:03 [debug    ] Standardization stats:
# 2026-04-16 18:51:03 [debug    ]   Grand mean range: [581.3600, 7798.1197]
# 2026-04-16 18:51:03 [debug    ]   Pooled std range: [87.8352, 951.1853]
# 2026-04-16 18:51:03 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:51:03 [debug    ]   Standardized data std: 1.4711 (should be ~1)
# 2026-04-16 18:51:03 [debug    ] Fitting L/S model
# 2026-04-16 18:51:03 [debug    ] L/S Model estimates:
# 2026-04-16 18:51:03 [debug    ]   Gamma hat shape: (8, 14)
# 2026-04-16 18:51:03 [debug    ]   Gamma hat range: [-2.6697, 3.6026]
# 2026-04-16 18:51:03 [debug    ]   Site 0 delta range: [0.6593, 1.6829]
# 2026-04-16 18:51:03 [debug    ]   Site 1 delta range: [0.6080, 2.0055]
# 2026-04-16 18:51:03 [debug    ]   Site 2 delta range: [0.5587, 1.8803]
# 2026-04-16 18:51:03 [debug    ]   Site 3 delta range: [0.7695, 1.6334]
# 2026-04-16 18:51:03 [debug    ]   Site 4 delta range: [0.2613, 1.5345]
# 2026-04-16 18:51:03 [debug    ]   Site 5 delta range: [0.5710, 1.4909]
# 2026-04-16 18:51:03 [debug    ]   Site 6 delta range: [0.3399, 1.3329]
# 2026-04-16 18:51:03 [debug    ]   Site 7 delta range: [0.3143, 1.7375]
# 2026-04-16 18:51:03 [debug    ] Finding priors
# 2026-04-16 18:51:03 [debug    ]   Gamma bar (mean location effect): [-0.17171665  0.02797746 -0.17296395  0.08708439  0.16363478  0.07595581
#  -0.41083663  0.36796052]
# 2026-04-16 18:51:03 [debug    ]   Tau^2 (variance of location effects): [1.50277414 0.87616331 0.87407054 1.45391426 1.04274694 1.63234342
#  0.93702717 1.48016852]
# 2026-04-16 18:51:03 [debug    ]   Mean tau^2: 1.224901 (higher = more heterogeneous effects)
# 2026-04-16 18:51:03 [debug    ] Finding parametric adjustments
# 2026-04-16 18:51:03 [debug    ] _iteration_solver converged in 3 iterations (change=0.000001)
# 2026-04-16 18:51:03 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:03 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:03 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:03 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:03 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:03 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:03 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:03 [debug    ] Transforming
# 2026-04-16 18:51:03 [debug    ] Making design matrix
# 2026-04-16 18:51:03 [debug    ] Sites encoded: 860 samples x 8 sites
# 2026-04-16 18:51:03 [debug    ] Design matrix shape: (860, 8)
# 2026-04-16 18:51:03 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:51:03 [debug    ] Standardizing data across features
# 2026-04-16 18:51:03 [debug    ] Standardization stats:
# 2026-04-16 18:51:03 [debug    ]   Grand mean range: [581.3600, 7798.1197]
# 2026-04-16 18:51:03 [debug    ]   Pooled std range: [87.8352, 951.1853]
# 2026-04-16 18:51:03 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:51:03 [debug    ]   Standardized data std: 1.4711 (should be ~1)
# 2026-04-16 18:51:03 [debug    ] Harmonizing data
# 2026-04-16 18:51:03 [debug    ] Transforming
# 2026-04-16 18:51:03 [debug    ] Making design matrix
# 2026-04-16 18:51:03 [debug    ] Sites encoded: 96 samples x 8 sites
# 2026-04-16 18:51:03 [debug    ] Design matrix shape: (96, 8)
# 2026-04-16 18:51:03 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:51:03 [debug    ] Standardizing data across features
# 2026-04-16 18:51:03 [debug    ] Standardization stats:
# 2026-04-16 18:51:03 [debug    ]   Grand mean range: [581.3600, 7798.1197]
# 2026-04-16 18:51:03 [debug    ]   Pooled std range: [87.8352, 951.1853]
# 2026-04-16 18:51:03 [debug    ]   Standardized data mean: 0.030122 (should be ~0)
# 2026-04-16 18:51:03 [debug    ]   Standardized data std: 1.4619 (should be ~1)
# 2026-04-16 18:51:03 [debug    ] Harmonizing data
# 2026-04-16 18:51:03 [debug    ] Fitting
# 2026-04-16 18:51:03 [debug    ] Making design matrix
# 2026-04-16 18:51:03 [debug    ] Fitted site encoder: 8 sites
# 2026-04-16 18:51:03 [debug    ] Sites encoded: 860 samples x 8 sites
# 2026-04-16 18:51:03 [debug    ] Design matrix shape: (860, 8)
# 2026-04-16 18:51:03 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:51:03 [debug    ] Final formula for smoothing: y ~ x0 + x1 + x2 + x3 + x4 + x5 + x6 + x7 - 1
# 2026-04-16 18:51:03 [debug    ] Standardizing data across features
# 2026-04-16 18:51:03 [info     ] Smoothing more than 10 variables may take several minutes of computation.
# 2026-04-16 18:51:06 [debug    ] Standardization stats:
# 2026-04-16 18:51:06 [debug    ]   Grand mean range: [588.9796, 7778.9830]
# 2026-04-16 18:51:06 [debug    ]   Pooled std range: [88.9052, 943.2953]
# 2026-04-16 18:51:06 [debug    ]   Standardized data mean: -0.000000 (should be ~0)
# 2026-04-16 18:51:06 [debug    ]   Standardized data std: 1.4697 (should be ~1)
# 2026-04-16 18:51:06 [debug    ] Fitting L/S model
# 2026-04-16 18:51:06 [debug    ] L/S Model estimates:
# 2026-04-16 18:51:06 [debug    ]   Gamma hat shape: (8, 14)
# 2026-04-16 18:51:06 [debug    ]   Gamma hat range: [-2.6990, 3.6565]
# 2026-04-16 18:51:06 [debug    ]   Site 0 delta range: [0.5672, 1.5566]
# 2026-04-16 18:51:06 [debug    ]   Site 1 delta range: [0.6112, 2.0235]
# 2026-04-16 18:51:06 [debug    ]   Site 2 delta range: [0.5594, 1.8278]
# 2026-04-16 18:51:06 [debug    ]   Site 3 delta range: [0.7462, 1.5664]
# 2026-04-16 18:51:06 [debug    ]   Site 4 delta range: [0.2808, 1.6020]
# 2026-04-16 18:51:06 [debug    ]   Site 5 delta range: [0.6186, 1.5828]
# 2026-04-16 18:51:06 [debug    ]   Site 6 delta range: [0.3202, 1.3662]
# 2026-04-16 18:51:06 [debug    ]   Site 7 delta range: [0.3530, 1.8064]
# 2026-04-16 18:51:06 [debug    ] Finding priors
# 2026-04-16 18:51:06 [debug    ]   Gamma bar (mean location effect): [-0.19837822  0.02796999 -0.1737352   0.07315888  0.19791925  0.09369641
#  -0.41974997  0.36588244]
# 2026-04-16 18:51:06 [debug    ]   Tau^2 (variance of location effects): [1.49094048 0.84714528 0.87521775 1.4499311  0.99880084 1.67631225
#  0.91639355 1.48494832]
# 2026-04-16 18:51:06 [debug    ]   Mean tau^2: 1.217461 (higher = more heterogeneous effects)
# 2026-04-16 18:51:06 [debug    ] Finding parametric adjustments
# 2026-04-16 18:51:06 [debug    ] _iteration_solver converged in 3 iterations (change=0.000001)
# 2026-04-16 18:51:06 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:06 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:06 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:06 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:06 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:06 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:06 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:06 [debug    ] Transforming
# 2026-04-16 18:51:06 [debug    ] Making design matrix
# 2026-04-16 18:51:06 [debug    ] Sites encoded: 860 samples x 8 sites
# 2026-04-16 18:51:06 [debug    ] Design matrix shape: (860, 8)
# 2026-04-16 18:51:06 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:51:06 [debug    ] Standardizing data across features
# 2026-04-16 18:51:06 [debug    ] Standardization stats:
# 2026-04-16 18:51:06 [debug    ]   Grand mean range: [588.9796, 7778.9830]
# 2026-04-16 18:51:06 [debug    ]   Pooled std range: [88.9052, 943.2953]
# 2026-04-16 18:51:06 [debug    ]   Standardized data mean: -0.000000 (should be ~0)
# 2026-04-16 18:51:06 [debug    ]   Standardized data std: 1.4697 (should be ~1)
# 2026-04-16 18:51:06 [debug    ] Harmonizing data
# 2026-04-16 18:51:06 [debug    ] Transforming
# 2026-04-16 18:51:06 [debug    ] Making design matrix
# 2026-04-16 18:51:06 [debug    ] Sites encoded: 96 samples x 8 sites
# 2026-04-16 18:51:06 [debug    ] Design matrix shape: (96, 8)
# 2026-04-16 18:51:06 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:51:06 [debug    ] Standardizing data across features
# 2026-04-16 18:51:06 [debug    ] Standardization stats:
# 2026-04-16 18:51:06 [debug    ]   Grand mean range: [588.9796, 7778.9830]
# 2026-04-16 18:51:06 [debug    ]   Pooled std range: [88.9052, 943.2953]
# 2026-04-16 18:51:06 [debug    ]   Standardized data mean: 0.007974 (should be ~0)
# 2026-04-16 18:51:06 [debug    ]   Standardized data std: 1.4329 (should be ~1)
# 2026-04-16 18:51:06 [debug    ] Harmonizing data
# 2026-04-16 18:51:06 [debug    ] Fitting
# 2026-04-16 18:51:06 [debug    ] Making design matrix
# 2026-04-16 18:51:06 [debug    ] Fitted site encoder: 8 sites
# 2026-04-16 18:51:06 [debug    ] Sites encoded: 861 samples x 8 sites
# 2026-04-16 18:51:06 [debug    ] Design matrix shape: (861, 8)
# 2026-04-16 18:51:06 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:51:06 [debug    ] Final formula for smoothing: y ~ x0 + x1 + x2 + x3 + x4 + x5 + x6 + x7 - 1
# 2026-04-16 18:51:06 [debug    ] Standardizing data across features
# 2026-04-16 18:51:06 [info     ] Smoothing more than 10 variables may take several minutes of computation.
# 2026-04-16 18:51:09 [debug    ] Standardization stats:
# 2026-04-16 18:51:09 [debug    ]   Grand mean range: [584.1919, 7749.5307]
# 2026-04-16 18:51:09 [debug    ]   Pooled std range: [88.8392, 931.9122]
# 2026-04-16 18:51:09 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:51:09 [debug    ]   Standardized data std: 1.4796 (should be ~1)
# 2026-04-16 18:51:09 [debug    ] Fitting L/S model
# 2026-04-16 18:51:09 [debug    ] L/S Model estimates:
# 2026-04-16 18:51:09 [debug    ]   Gamma hat shape: (8, 14)
# 2026-04-16 18:51:09 [debug    ]   Gamma hat range: [-2.7419, 3.7531]
# 2026-04-16 18:51:09 [debug    ]   Site 0 delta range: [0.5801, 1.6086]
# 2026-04-16 18:51:09 [debug    ]   Site 1 delta range: [0.5742, 2.1200]
# 2026-04-16 18:51:09 [debug    ]   Site 2 delta range: [0.5810, 1.9241]
# 2026-04-16 18:51:09 [debug    ]   Site 3 delta range: [0.7380, 1.6393]
# 2026-04-16 18:51:09 [debug    ]   Site 4 delta range: [0.2501, 1.6204]
# 2026-04-16 18:51:09 [debug    ]   Site 5 delta range: [0.6474, 1.5857]
# 2026-04-16 18:51:09 [debug    ]   Site 6 delta range: [0.3361, 1.3921]
# 2026-04-16 18:51:09 [debug    ]   Site 7 delta range: [0.3662, 1.6383]
# 2026-04-16 18:51:09 [debug    ] Finding priors
# 2026-04-16 18:51:09 [debug    ]   Gamma bar (mean location effect): [-0.21313371  0.00950585 -0.18869501  0.0767618   0.1912916   0.09293254
#  -0.39263464  0.4116296 ]
# 2026-04-16 18:51:09 [debug    ]   Tau^2 (variance of location effects): [1.50522745 0.90394464 0.89108089 1.40491634 1.03970248 1.71858525
#  0.98210374 1.53045387]
# 2026-04-16 18:51:09 [debug    ]   Mean tau^2: 1.247002 (higher = more heterogeneous effects)
# 2026-04-16 18:51:09 [debug    ] Finding parametric adjustments
# 2026-04-16 18:51:09 [debug    ] _iteration_solver converged in 3 iterations (change=0.000001)
# 2026-04-16 18:51:09 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:09 [debug    ] _iteration_solver converged in 3 iterations (change=0.000001)
# 2026-04-16 18:51:09 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:09 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:09 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:09 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:09 [debug    ] _iteration_solver converged in 3 iterations (change=0.000000)
# 2026-04-16 18:51:09 [debug    ] Transforming
# 2026-04-16 18:51:09 [debug    ] Making design matrix
# 2026-04-16 18:51:09 [debug    ] Sites encoded: 861 samples x 8 sites
# 2026-04-16 18:51:09 [debug    ] Design matrix shape: (861, 8)
# 2026-04-16 18:51:09 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:51:09 [debug    ] Standardizing data across features
# 2026-04-16 18:51:09 [debug    ] Standardization stats:
# 2026-04-16 18:51:09 [debug    ]   Grand mean range: [584.1919, 7749.5307]
# 2026-04-16 18:51:09 [debug    ]   Pooled std range: [88.8392, 931.9122]
# 2026-04-16 18:51:09 [debug    ]   Standardized data mean: 0.000000 (should be ~0)
# 2026-04-16 18:51:09 [debug    ]   Standardized data std: 1.4796 (should be ~1)
# 2026-04-16 18:51:09 [debug    ] Harmonizing data
# 2026-04-16 18:51:09 [debug    ] Transforming
# 2026-04-16 18:51:09 [debug    ] Making design matrix
# 2026-04-16 18:51:09 [debug    ] Sites encoded: 95 samples x 8 sites
# 2026-04-16 18:51:09 [debug    ] Design matrix shape: (95, 8)
# 2026-04-16 18:51:09 [debug    ] Setting up smoothing using B-Splines
# 2026-04-16 18:51:09 [debug    ] Standardizing data across features
# 2026-04-16 18:51:09 [debug    ] Standardization stats:
# 2026-04-16 18:51:09 [debug    ]   Grand mean range: [584.1919, 7749.5307]
# 2026-04-16 18:51:09 [debug    ]   Pooled std range: [88.8392, 931.9122]
# 2026-04-16 18:51:09 [debug    ]   Standardized data mean: 0.078186 (should be ~0)
# 2026-04-16 18:51:09 [debug    ]   Standardized data std: 1.4833 (should be ~1)
# 2026-04-16 18:51:09 [debug    ] Harmonizing data

# %% [markdown]
# ### Plot results

# %%
# %% Plotting results
fig, ax = plt.subplots(1, 1, figsize=[15, 7])

harm_methods = [
    "ComBatGAM",
    "Unharmonized Baseline",
]

sns.swarmplot(data=results, x="Name", y="bACC", hue="Method", hue_order=harm_methods, dodge=True, ax=ax)

sns.boxplot(
    data=results,
    color="w",
    zorder=1,
    x="Name",
    y="bACC",
    hue="Method",
    hue_order=harm_methods,
    dodge=True,
    ax=ax,
    palette=["w"] * len(harm_methods),
)
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[: len(harm_methods)], labels[: len(harm_methods)])
ax.axhline(0.5, lw=2, color="k", ls="--", alpha=0.7, label="Chance level")
plt.grid(axis="y")
plt.grid(axis="y")
plt.xticks(rotation=45)

plt.show()
# %%

# %% [markdown]
# ## 6) Take-home message
# - The final markdown note states:
#     - `ComBatGAM` removes the `eos` site effect while preserving the `true` signal.
# - The plot and results demonstrate the method’s ability to reduce spurious site-related variation and maintain true biological effect performance.
