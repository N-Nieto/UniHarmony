# %% [markdown]
# (example_multisite_data_characterization_example)=

# %% [markdown]
# # Characterize a multisite problem using UniHarmony

# %% [markdown]
# ## The first step before applying any harmonization technique is to understand and characterize our data

# %%
# Imports
from uniharmony import verbosity
from uniharmony.datasets import make_multisite_classification
from uniharmony.datasets._multisite_data_characterization import (
    get_site_data_statistics,
    print_statistics_summary,
)


verbosity("warning")

# %% [markdown]
# ## Let's use the multisite data generator to simulate some data

# %%
print("Generating example data...")
X, y, sites = make_multisite_classification(
    n_sites=3,
    n_samples=100,
    n_features=10,
    n_classes=3,
    random_state=42,
)

print("\n" + "=" * 60)
# Out:
# Generating example data...
#
# ============================================================

# %% [markdown]
# # Now lets compute some statistics

# %%
print("Computing statistics...")
print("=" * 60)

# Compute statistics
stats = get_site_data_statistics(
    X=X,
    y=y,
    sites=sites,
    feature_names=[f"feat_{i}" for i in range(X.shape[1])],
    compute_comprehensive=True,
)
verbosity("info")
# Print summary
print_statistics_summary(stats)
# Out:
# Computing statistics...
# ============================================================
# 2026-04-15 15:45:06 [info     ] ============================================================
# 2026-04-15 15:45:06 [info     ] DATASET STATISTICS SUMMARY
# 2026-04-15 15:45:06 [info     ] ============================================================
# 2026-04-15 15:45:06 [info     ]
# OVERALL:
# 2026-04-15 15:45:06 [info     ]   Samples: 100
# 2026-04-15 15:45:06 [info     ]   Features: 10
# 2026-04-15 15:45:06 [info     ]   Sites: 3
# 2026-04-15 15:45:06 [info     ]   Classes: 3
# 2026-04-15 15:45:06 [info     ]
# CLASS DISTRIBUTION:
# 2026-04-15 15:45:06 [info     ]   class_0: 31 samples (31.0%)
# 2026-04-15 15:45:06 [info     ]   class_1: 37 samples (37.0%)
# 2026-04-15 15:45:06 [info     ]   class_2: 32 samples (32.0%)
# 2026-04-15 15:45:06 [info     ]
# SITE DISTRIBUTION:
# 2026-04-15 15:45:06 [info     ]   site_0: 34 samples (34.0%)
# 2026-04-15 15:45:06 [info     ]   site_1: 33 samples (33.0%)
# 2026-04-15 15:45:06 [info     ]   site_2: 33 samples (33.0%)
# 2026-04-15 15:45:06 [info     ]
# SITE STATISTICS (summary):
# 2026-04-15 15:45:06 [info     ]   site_0:
# 2026-04-15 15:45:06 [info     ]     Samples: 34
# 2026-04-15 15:45:06 [info     ]     Class distribution: {'class_0': 10, 'class_1': 16, 'class_2': 8}
# 2026-04-15 15:45:06 [info     ]   site_1:
# 2026-04-15 15:45:06 [info     ]     Samples: 33
# 2026-04-15 15:45:06 [info     ]     Class distribution: {'class_0': 10, 'class_1': 8, 'class_2': 15}
# 2026-04-15 15:45:06 [info     ]   site_2:
# 2026-04-15 15:45:06 [info     ]     Samples: 33
# 2026-04-15 15:45:06 [info     ]     Class distribution: {'class_0': 11, 'class_1': 13, 'class_2': 9}
# 2026-04-15 15:45:06 [info     ]
# FEATURE STATISTICS (first 5 features):
# 2026-04-15 15:45:06 [info     ]   feat_0: mean=-1.5453, std=1.9632
# 2026-04-15 15:45:06 [info     ]   feat_1: mean=-1.6023, std=1.9825
# 2026-04-15 15:45:06 [info     ]   feat_2: mean=-1.6290, std=1.9201
# 2026-04-15 15:45:06 [info     ]   feat_3: mean=-1.4402, std=1.8426
# 2026-04-15 15:45:06 [info     ]   feat_4: mean=-1.7795, std=2.0436
# 2026-04-15 15:45:06 [info     ]
# CORRELATIONS:
# 2026-04-15 15:45:06 [info     ]   Average Inter-Site Correlation: 0.0207
# 2026-04-15 15:45:06 [info     ] ============================================================
